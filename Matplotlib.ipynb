# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanGH/google-colaboratory-practical-statistics-for-data-scientists/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
x = plt.plot(x,y, color='green', linewidth=2)

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My first graph')
# Out:
# Text(0.5, 1.0, 'My first graph')

# %%
# subplot(nrows, ncols, index, **kwargs)
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# add_axes(rect, projection=None, polar=False, **kwargs)
# left, bottom, width, height
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Lable')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0.1,0.5,0.5])
axes2 = fig.add_axes([0.2,0.2,0.3,0.15])

axes1.plot(y,x, 'g--', label="x**2")
axes1.set_title('Larger plot')

axes2.plot(x,y, 'r--')
axes2.set_title('Small plot')
# Out:
# Text(0.5, 1.0, 'Small plot')

# %%
x = np.linspace(0,5,11)
y = x**2

fig, axes = plt.subplots(nrows=1, ncols=2)

for axe in axes:
  axe.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)

axes[0].plot(y,x,label='x**2')
axes[0].legend(loc=(0.1,0.9))

axes[1].plot(y,x,label="x**2")

# %%
fig = plt.figure(figsize=(3,2), dpi=100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
